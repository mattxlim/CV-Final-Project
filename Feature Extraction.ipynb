# %%
import os
import numpy as np
import pandas as pd
import cv2  
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from matplotlib import pyplot as plt

from sklearn import preprocessing

# %%
# Initialise image data generator
# With validation split


# Add rotation range

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                               validation_split=0.2)

# %%
train_path = './Downloads/CV Project/train'

# %%
# Import train labels from csv
train_labels = pd.read_csv('/Downloads/CV Project/train.csv', dtype=str)
train_labels['id'] = train_labels['id'].apply(lambda x: '{}.jpg'.format(x))

# Preprocess to get categorical class from coordinates. "x,y" used
train_labels['xy'] = train_labels['x'] + "," + train_labels['y']


# Integer encoding for coordinate label
train_labels['encoded'] = preprocessing.LabelEncoder().fit_transform(train_labels['xy'])
train_labels['encoded'] = train_labels['encoded'].apply(str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9fe314f21459> in <module>()
#       1 # Import train labels from csv
# ----> 2 train_labels = pd.read_csv('/Downloads/CV Project/train.csv', dtype=str)
#       3 train_labels['id'] = train_labels['id'].apply(lambda x: '{}.jpg'.format(x))
#       4
#       5 # Preprocess to get categorical class from coordinates. "x,y" used
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New section
